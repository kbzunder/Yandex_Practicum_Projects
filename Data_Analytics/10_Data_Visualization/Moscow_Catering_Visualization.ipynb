# %% [markdown]
# # <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Привет! Меня зовут Алексей Тюрин, я буду делать ревью твоей работы. Давай будем общаться на «ты».
#
# У тебя хорошая, аккуратная работа 👍. Есть несколько неточностей: стоит поискать дубликаты, поправить пункт про "что характерно для сетевых завдеений", выделить побольше улиц, выделить все районы для улиц из топ-10 (для каждой улицы) и чуит развернуть вывод. Можешь посмотреть остальные комментарии и задать вопросы, если будут :)
#
# ---
# Комментарии делятся на 3 группы:
#
# Зелёным цветом отмечены комментарии, либо подчёркивающие удачные решения, либо содержащие какую-то дополнительную информацию или советы, они формально не требуют правки, но правки приветствуются. Выделены они так:
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Тут текст
# </div>
#
# Жёлтым цветом выделены правки, которые желательны:
#
# <div class="alert alert-warning"; style="border-left: 7px solid yellow" >
# <h3>!! Комментарий ревьюера</h3>
#
# Тут текст
# </div>
#
# Красным выделены правки, которые обязательны
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <h3>👀 Комментарий ревьюера</h3>
#
# Тут текст
# </div>
#
# Давай работать над проектом в диалоге: если ты **что-то меняешь** в проекте по моим рекомендациям — **пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если оставляешь комментарии на какой-то итерации ревью, пиши что-то вроде `комментарий студента V.{номер итерации}`
# </div>
#
# Цвет можно сделать, например, так
#
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>Комментарий студента</h3>
# Ревьюер душнила :)
# </div>
#
# Или так:
#
# <div class="alert alert-info" style="background:#ffdbf1;color:#2e00ab;border-left:7px solid #2e00ab">
# <h3>Комментарий студента </h3>
#     ...
# </div>

# %% [markdown]
# # Рынок заведений общественного питания Москвы

# %% [markdown]
# 1.[Знакомство с данными](#data_info)
#     1.1 [Загрузка данных](#data_download)
#     1.2 [Составление профиля данных](#profiling)
# 2.[Анализ данныз](#data_analysis)
#     2.1 [Исследуйте соотношение видов объектов общественного питания по количеству. Постройте график.](#three-one)
#     2.2 [Исследуйте соотношение сетевых и несетевых заведений по количеству. Постройте график](#three-two)
#     2.3 [Для какого вида объекта общественного питания характерно сетевое распространение?](#tree-three)
#     2.4 [Что характерно для сетевых заведений: много заведений с небольшим числом посадочных мест в каждом или мало заведений с большим количеством посадочных мест?](#three-four)
#     2.5 [Для каждого вида объекта общественного питания опишите среднее количество посадочных мест. Какой вид предоставляет в среднем самое большое количество посадочных мест? Постройте графики.](#three-five)
#     2.6 [Выделите в отдельный столбец информацию об улице из столбца address](#three-six)
#     2.7 [Постройте график топ-10 улиц по количеству объектов общественного питания. Воспользуйтесь внешней информацией и ответьте на вопрос — в каких районах Москвы находятся эти улицы?](#three-seven)
#     2.8 [Найдите число улиц с одним объектом общественного питания. Воспользуйтесь внешней информацией и ответьте на вопрос — в каких районах Москвы находятся эти улицы?](#three-eight)
#     2.9 [Посмотрите на распределение количества посадочных мест для улиц с большим количеством объектов общественного питания. Какие закономерности можно выявить?](#three-nine)
# 3.[Общий вывод](#Conclusion)

# %%
import pandas as pd 
pd.options.display.float_format = '{:,.0f}'.format
import datetime as dt
from pandas_profiling import ProfileReport
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from plotly import graph_objects as go
import plotly.express as px 
import kaleido

import numpy as np
# import geopandas as gpd
# from shapely.geometry import Point

import requests
import re
from bs4 import BeautifulSoup

# %%
! pip install -U kaleido

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Здорово, что импорыт собраны в начале, так сразу понятно, какие у проекта зависимости.
#
# Все предупреждения не стоит выключать, тут можно посмотреть способы https://stackoverflow.com/questions/14463277/how-to-disable-python-warnings Если коротко, то лучше выключать те, которые надо, каждый модуль может свои предупреждения определять, как например `SetCopyOnWarning`, это который про присваивания. Его можно убрать вообще без фильров:
#     `pd.set_option('chained_assignment', None)`
#
# `%matplotlib inline` уже не нужен: https://stackoverflow.com/questions/65934740/is-matplotlib-inline-still-needed#:~:text=The%20only%20reason%20%25matplotlib%20inline,object%2C%20with%20something%20like%20matplotlib.
#
# Ещё кажется, что не все имопрты используются
# </div>

# %% [markdown]
# <div class="alert alert-info" style="background:#ffdbf1;color:#2e00ab;border-left:7px solid #2e00ab">
# <h3>У меня в VSCode без inline ничего не работает.</h3>
# <h3>Как можно сделать так, чтобы один стиль графиков на всю тетрадку применялся?</h3>
#     ...
# </div>

# %%
 # Если pandasProfiling вызывает ошибку
 # pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# А почему именно с гитхаба, а не с `pypi`?
# </div>

# %% [markdown]
# <a id="data_info"></a>
# ## 1. Знакомство с данными

# %% [markdown]
# <a id='data_download'></a>
# ### 1.1 Загрузка данных

# %%
try:
    data = pd.read_csv('/Users/ulia/Downloads/rest_data.csv')
except FileNotFoundError :
    data = pd.read_csv('/datasets/rest_data.csv')

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# В `except` стоит указывать конкретый тип исключения, чтобы не ловить лишних. Выше это `FileNotFoundError`</div>

# %%
display(data.head())
print()
data.info()
# Out:
#        id             object_name chain object_type  \
# 0  151635                 СМЕТАНА   нет        кафе
# 1   77874                  Родник   нет        кафе
# 2   24309         Кафе «Академия»   нет        кафе
# 3   21894              ПИЦЦЕТОРИЯ    да        кафе
# 4  119365  Кафе «Вишневая метель»   нет        кафе
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15366 entries, 0 to 15365
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           15366 non-null  int64
#  1   object_name  15366 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Датафреймы выводить стоит всё же через `display`. `info` делает вывод сам, поэтому его в `print` оборачивать не нужно, можно выше заметить, что выводится `None`
# </div>

# %%
data['object_type'] = data['object_type'].str.replace('предприятие быстрого обслуживания','фастфуд').replace('магазин (отдел кулинарии)','кулинария')

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Может быть нежелательно изменять оригинальные названия. В качесиве алтернативы, можно перенести в них слова на графиках</div>

# %% [markdown]
# <div class="alert alert-info" style="background:#ffdbf1;color:#2e00ab;border-left:7px solid #2e00ab">
# <h3>Про график не поняла</h3>
#
#     ...
# </div>

# %%
data['object_type'].unique()
# Out:
# array(['кафе', 'столовая', 'закусочная', 'фастфуд', 'ресторан',
#        'кафетерий', 'буфет', 'бар', 'кулинария'], dtype=object)

# %% [markdown]
# <a id='profiling'></a>
# ### 1.2 Составление профиля данных

# %%
ProfileReport(data)
# Out:
# ...
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.37it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-06-16 10:14:16.826692&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <h3>👀 Комментарий ревьюера</h3>
#
# Библиотека с профайлингом классная, но она не всё показывает. Тут есть уникальный столбец `id`, поэтому с ним бессмысленно искать дубликаты, зато можно посмотреть без него. Такой столбец часто автоинкрементируется в реляционных базах данных, даже если вставляется уже формально существующая запись.
# </div>

# %%
data = data.drop(data.index[data.drop('id',axis=1).duplicated()])

# %%
data.drop('id',axis=1).duplicated().sum()
# Out:
# 0

# %%
data['object_name'] = data['object_name'].str.lower()

# %%
data = data.drop(data.index[data.drop('id',axis=1).duplicated()])

# %%
data.sort_values(by='object_name')
# Out:
#            id                       object_name chain object_type  \
# 1095    84529                           1-й мок   нет    столовая
# 7170    28685  1-ый московский кадетский корпус   нет    столовая
# 14879  213667               100 личная столовая   нет    столовая
# 14878  213840                   100 личное кафе   нет        кафе
# 1517    24520                         1001 ночь   нет    ресторан
# ...       ...                               ...   ...         ...
# 12142  191116                          ёбидоёби   нет        кафе
# 3732    59397                               ёрш    да    ресторан
# 932     71428                               ёрш    да        кафе
# 9237   160244                               ёрш    да    ресторан
# 7699    26945                               ёрш    да    ресторан
#
#                                                  address  number
# 1095      город Москва, Стартовая улица, дом 1, корпус 1     100
# ...

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Можно выше обратить внимание на 0 посадочных мест у довольно большого числа завдеений. Чтобы убедиться, что картина правдоподобна, можно сгруппировать заведения по `object_type` и для каждого типа посмотреть на долю таких заведений.
#
# </div>

# %%
word_list = ['макдон','бургер-','крошка-','планета']

# %%
dupl_list = []
for word in word_list:
    pattern = re.compile(word)
    matches = [x for x in data['object_name'] if pattern.match(x)]
    dupl_list.append(set(matches))

# %%
dupl_list
# Out:
# [{'макдоналдс'},
#  set(),
#  {'крошка-картошка'},
#  {'планета боулинг', 'планета сибирь', 'планета суши'}]

# %% [markdown]
# <div class="alert alert-info" style="background:#ffdbf1;color:#2e00ab;border-left:7px solid #2e00ab">
# <h3>Принцип такой?</h3>
#     ...
# </div>

# %% [markdown]
# <div class="alert alert-info" style="background:#ffdbf1;color:#2e00ab;border-left:7px solid #2e00ab">
# <h3>Подскажи, пожалуйста, можно ли показывать все результаты без ограничений? например, как вывести на экран data['object_name'].unique() полность? </h3>
#     ...
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Перед тем как смотреть на дубликаты, можно заметить, что как минимум названия написаны разным регистром, т.е. лучше привести к одному, а как максимум написаны в разнобой, тут уже необязательно, но можно попробовать привести всё к одному виду (это также будет полезно, т.к. далее надо группировать заведения по сетям), типа макдональс, макдоналдс, mcdonalds $\to$ макдоналдс. Тут можно либо руками, либо поиграться с метриками похожести слов https://ru.wikipedia.org/wiki/%D0%A0%D0%B0%D1%81%D1%81%D1%82%D0%BE%D1%8F%D0%BD%D0%B8%D0%B5_%D0%9B%D0%B5%D0%B2%D0%B5%D0%BD%D1%88%D1%82%D0%B5%D0%B9%D0%BD%D0%B0
#
# Для способа с вики кажется достаточным положить цену замены русской буквы на аналогичную английскую в 0 и убрать стоп-слова вроде названия типа заведения в названии. Также нужно составить список всех названий сетей, с которым будем матчить название из датафрейма, его можно либо где-то извне собрать, либо заполнить итеративно, пользуясь также редакторским расстоянием, т.е. добавлять название из столбца `object_name` в множество уникальных названия, только если оно не похоже ни на одно из уже присутствующих и не добавлять, если есть похожие
#
# Альтернативно можно пользоваться каким-нибудь 2гис апи и брать названия заведений из запроса с названием из таблички, там такая функциональность (поиск похожих названий) уже реализована, но это может быть платным.
#
# Выше с апи и метриками возиться необязательно, это скорее то, на что можно на досуге посмотреть, но руками для крупных сетей можно и поправить.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="background:#ffdbf1;color:#2e00ab;border-left:7px solid #2e00ab">
# <h3>levenstein модуль так и не поставился, те не работал, к сожалению</h3>
#     ...
# </div>

# %% [markdown]
# <a id="data_analysis"></a>
# ## 2. Анализ данных

# %% [markdown]
# <a id="three-one"></a>
# ### 2.1 Исследуйте соотношение видов объектов общественного питания по количеству. Постройте график.

# %%
fig = px.bar(data.groupby('object_type',as_index=False)\
    .agg({'id':'count'})\
    .rename(columns={'id':'count'})\
    .sort_values(by='count', ascending=False), x='object_type',y='count', 
    labels={'object_type':'Типы объектов питания','count':'Количество объектов'},
    title='Распределение объектов общественного питания по типам')
fig.write_image("/Users/ulia/yandex_DA/Yandex_Practicum_Projects/Data_Analytics/10_Data_Visualization/Images/fig1.jpeg")
fig.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Верно, хотя раз у тебя `pandas profiling` в `html`, то можно было в `plotly` графики строить. Тут можно посмотреть, как можно увеличить качество у графиков в тетрадке: https://blakeaw.github.io/2020-05-25-improve-matplotlib-notebook-inline-res/
# </div>

# %% [markdown]
# ### Как видно из графика, больше всего кафе, столовых и ресторанов, а меньше всего отделов кулинарии в магазинах

# %% [markdown]
# <a id="three-two"></a>
# ### 2.2 Исследуйте соотношение сетевых и несетевых заведений по количеству. Постройте график

# %%
fig = px.pie(data.groupby('chain', as_index=False).agg({'id':'count'}), values='id',
    title='Распределение сетевых и несетевых заведений в Москве', names='chain')
fig.write_image("/Users/ulia/yandex_DA/Yandex_Practicum_Projects/Data_Analytics/10_Data_Visualization/Images/fig2.jpeg")
fig.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Тут хорошо бы пайчарт подошёл</div>

# %% [markdown]
# ### В Москве в 4 раза меньше сетевых заведений.

# %%
fig = px.bar(data.groupby(['object_type','chain'],as_index=False)\
    .agg({'id':'count'})\
    .rename(columns={'id':'count'})\
    .sort_values(by='count', ascending=False), color='chain', x='object_type',y='count', 
    labels={'object_type':'Типы объектов питания','count':'Количество объектов'},
    title='Распределение сетевых/несетевых объектов по типам')
fig.write_image("/Users/ulia/yandex_DA/Yandex_Practicum_Projects/Data_Analytics/10_Data_Visualization/Images/fig3.jpeg")
fig.show()

# %% [markdown]
# ### Видим, что во всем типам объектом превалируют несетевые объекты. Почти нет сетевых столовых.

# %% [markdown]
# <a id='three-three'></a>
# ### 2.3 Для какого вида объекта общественного питания характерно сетевое распространение?

# %% [markdown]
# ### Самый большой процент сетевых объектов в предприятиях быстрого обслуживания

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Чтобы соотношение увидеть, лучше было бы сделать график не-stacked и нормализовать колонки, т.е. чтобы сумма синих и зеленых давала 1 для каждого типа. А так, всё верно
# </div>

# %% [markdown]
# <a id='three-four'></a>
# ### 2.4 Что характерно для сетевых заведений: много заведений с небольшим числом посадочных мест в каждом или мало заведений с большим количеством посадочных мест?

# %%
fig = px.histogram(data.query('chain=="да"'), x="number",  labels={
                     "number": "Количество посадочных мест"
                 },
                title="Распределение посадочных мест в сетевых заведениях Москвы")
fig.write_image("/Users/ulia/yandex_DA/Yandex_Practicum_Projects/Data_Analytics/10_Data_Visualization/Images/fig4.jpeg")
fig.update_annotations(title='Распределение')

# %%
fig = px.box(data.query('chain=="да"'), x="number", labels={'number':'кол-во посадочных мест'},
                title="Распределение посадочных мест в сетевых заведениях Москвы")
fig.write_image("/Users/ulia/yandex_DA/Yandex_Practicum_Projects/Data_Analytics/10_Data_Visualization/Images/fig12.jpeg")
fig.show()

# %% [markdown]
# ### Среди сетевых заведений медианное значинеие - 40 мест, преобладают небольшие заведения

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <h3>👀 Комментарий ревьюера</h3>
#
# Здесь помимо числа посадочных мест нужно смотреть на число завдеений в сетях. Для большего понимания можно переформулировать вопрос так:
#
# Если взять **случайную сеть**, то вероятность какого события выше?
# <li>Наткнуться на сеть с <b>большим</b> числом посадочных мест и <b>небольшим</b> числом заведений в сети</li>
# <li>Наткнуться на сеть с <b>небольшим</b> числом посадочных мест и <b>большим</b> числом заведений в сети</li>
# <li>Наткнуться на сеть с <b>небольшим</b> числом посадочных мест и <b>небольшим</b> числом заведений в сети</li>
# <li>Наткнуться на сеть с <b>большим</b> числом посадочных мест и <b>большим</b> числом заведений в сети</li>
#
# Чтобы в таком виде на него ответить, нужно сетевых заведения сгруппировать по сетям, т.е. по `object_name` и рассмотреть в них число заведений и среднее число посадочных мест. Далее нужно определить, какое число завдеений в сети можно считать большим, а какое небольшим и то же самое сделать для числа посадочных мест, например, ориентируясь по квантилям. Далее останется разбить сети на 4 группы выше и посмотреть в какой группе больше сетей. Сети, состоящие из 1 завдеения можно отбросить, они возникают в основном из-за разного написания названий
# </div>

# %%
chain_data = data.query('chain=="да"').groupby('object_name',as_index=False)\
    .agg({'id':'count', 'number':'mean'})\
    .rename(columns={'id':'num_obj','number':'mean_seats'})

# %%
chain_data = chain_data.query('num_obj > 1')

# %%
chain_data.describe()
# Out:
#        num_obj  mean_seats
# count      246         246
# mean        11          59
# std         23          50
# min          2           0
# 25%          2          21
# 50%          4          44
# 75%          7          85
# max        157         259

# %%
def groups(row):
    if (row['mean_seats'] > 85) and (row['num_obj'] < 3):
        return '>85 мест,<3 объектов'
    elif (row['mean_seats']  >= 85) and (row['num_obj'] >=7):
        return '>85 мест, >=7 объектов'
    elif (row['mean_seats']  <20) and (row['num_obj'] >=7):
        return '<20 мест, >=7 объектов'
    elif  (row['mean_seats']  <20) and (row['num_obj'] <=3):
        return '<20 мест, <=3 объектов'
    else:
        return 'прочие'

# %%
chain_data['group'] = chain_data.apply(groups,axis=1)

# %%
chain_data.head()
# Out:
#            object_name  num_obj  mean_seats                   group
# 3           bocconcino        3          67                  прочие
# 6          burger club        3          20                  прочие
# 8   coffeeshop company        4          47                  прочие
# 9                cofix       25          10  <20 мест, >=7 объектов
# 11             correas        3          44                  прочие

# %%
fig = px.bar(chain_data.groupby('group',as_index=False)\
    .agg({'object_name':'count'}), x='group',y='object_name',
    labels={'object_name':'количество объектов','group':'группа'},
    title='Группы сетевых объектов')
fig.write_image("/Users/ulia/yandex_DA/Yandex_Practicum_Projects/Data_Analytics/10_Data_Visualization/Images/fig5.jpeg")
fig.show()

# %% [markdown]
# Если исключить срдение данные по "прочим", то наиболее веротяно увидеть небольшое количество сетевых объектов с небольшим количеством мест.

# %% [markdown]
# <a id='three-five'></a>
# ### 2.5 Для каждого вида объекта общественного питания опишите среднее количество посадочных мест. Какой вид предоставляет в среднем самое большое количество посадочных мест? Постройте графики.

# %%
data.groupby('object_type',as_index=False).agg({'number':'mean'}).sort_values(by='number',ascending=False)
# Out:
#   object_type  number
# 7    столовая     130
# 6    ресторан      97
# 1       буфет      51
# 0         бар      44
# 3        кафе      40
# 8     фастфуд      21
# 4   кафетерий       9
# 2  закусочная       8
# 5   кулинария       6

# %%
fig = px.bar(data.groupby('object_type',as_index=False).agg({'number':'mean'})\
    .sort_values(by='number',ascending=False), y='number', x='object_type', title='Среднее количество посадочных мест', 
    labels={'object_type':'Тип объекта', 'number':'Среднее кол-во посадочных мест'})
fig.write_image("/Users/ulia/yandex_DA/Yandex_Practicum_Projects/Data_Analytics/10_Data_Visualization/Images/fig6.jpeg")
fig.show()

# %%
fig = px.box(data, y='number', x='object_type',title='Среднее количество посадочных мест', 
    labels={'object_type':'Тип объекта', 'number':'количество мест'})
fig.write_image("/Users/ulia/yandex_DA/Yandex_Practicum_Projects/Data_Analytics/10_Data_Visualization/Images/fig7.jpeg")
fig.show()

# %% [markdown]
# Медианное количество посадочных мест наибольшее в столовых, во всех типах общественного питания присуствует много выбросов. Средние значения очень сильно зависят от выбросов.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Т.к. в столцбе есть выбросы, то может быть лучше смотреть на медиану</div>

# %% [markdown]
# ### Самое большое количество посадочных мест в среднем в столовых - 130, ресторанах - 97 и буфетах - 51

# %% [markdown]
# <a id='three-six'></a>
# ### 2.6 Выделите в отдельный столбец информацию об улице из столбца address

# %%
words = ['улица','деревня','поселение','аллея', 'бульвар',  "линия", "мост", "набережная", "парк", "переулок", "площадь", "посёлок", "проезд", "проектируемый проезд", 'просека', 'проспект', 'тупик','шоссе']
def streets(address):
    add_list = address.split(',')
    for word in words:
        for lst in add_list:
            if word in lst:
                return lst

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <h3>👀 Комментарий ревьюера</h3>
#
# Хороший способ, но многих типов улиц не хватает. Можно ниже посмотреть на количество пропусков. Проще всего нагуглить все типы завдеений и указать их в `words`
# </div>

# %%
data['streets'] = data['address'].apply(streets)

# %%
# Код ревьюера
data[data['streets'].isna() & (~data['address'].str.contains('Зеленоград'))]
# Out:
#            id                                        object_name chain  \
# 394    150654                                               love   нет
# 1799   152815    предприятие быстрого обслуживания «бургер кинг»    да
# 1800   152821  предприятие быстрого обслуживания «крошка карт...    да
# 1801    70614                      кафе-кондитерская «селезнефф»   нет
# 1802   106196                                      бар «попкорн»   нет
# ...       ...                                                ...   ...
# 14575  210165                                               кафе   нет
# 14795  221526                                             pivbar   нет
# 14817  219644                                               кафе   нет
# 15097  209001                            бургер кинг burger king    да
# 15274  211230          предприятие быстрого обслуживания «милти»    да
#
#       object_type                                            address  number  \
# ...

# %% [markdown]
# <a id='three-seven'></a>
# ### 2.7 Постройте график топ-10 улиц по количеству объектов общественного питания. Воспользуйтесь внешней информацией и ответьте на вопрос — в каких районах Москвы находятся эти улицы?

# %% [markdown]
# ### Получим данные из онлайн базы данных всех улиц Москвы:
# [Все улицы Москвы](http://xn----7sbbj7ab0abgod6a9h.xn--80adxhks/%D0%B2%D1%81%D0%B5_%D1%83%D0%BB%D0%B8%D1%86%D1%8B_%D0%BC%D0%BE%D1%81%D0%BA%D0%B2%D1%8B)

# %%
content_many = []
for page in range(1,310):
    URL = 'http://xn----7sbbj7ab0abgod6a9h.xn--80adxhks/%D0%B2%D1%81%D0%B5_%D1%83%D0%BB%D0%B8%D1%86%D1%8B_%D0%BC%D0%BE%D1%81%D0%BA%D0%B2%D1%8B' + '?page='+str(page)
    req = requests.get(URL)
    soup = BeautifulSoup(req.text, 'lxml')
    table = soup.find('table', attrs={'class':'table table-striped table-bordered'})
    for row in table.find_all('tr'):
        if not row.find_all('th'): 
            content_many.append([element.text for element in row.find_all('td')])

# %%
URL = 'http://xn----7sbbj7ab0abgod6a9h.xn--80adxhks/%D0%B2%D1%81%D0%B5_%D1%83%D0%BB%D0%B8%D1%86%D1%8B_%D0%BC%D0%BE%D1%81%D0%BA%D0%B2%D1%8B' + '?page='+str(page)
req0 = requests.get(URL)
soup0 = BeautifulSoup(req.text, 'lxml')
table0 = soup.find('table', attrs={'class':'table table-striped table-bordered'})
heading_table = []
for row in table0.find_all('th'):
    heading_table.append(row.text)
content0 = []
for row in table0.find_all('tr'):
    if not row.find_all('th'): 
        content0.append([element.text for element in row.find_all('td')])

# %%
content_many.extend(content0)

# %%
regions = pd.DataFrame(content_many, columns=heading_table)

# %%
regions.head()
# Out:
#   Наименование    Тип  Индекс                 Административный округ  \
# 0
# 1            1    мкр  142793  Новомосковский административный округ
# 2     1 Маевки  аллея  111395       Восточный административный округ
# 3        1 Мая     ул  124365  Зеленоградский административный округ
# 4          1-й    мкр  142784  Новомосковский административный округ
#
#                    Район
# 0
# 1  Десёновское поселение
# 2          район Вешняки
# 3          район Крюково
# 4   Внуковское поселение

# %%
vocab = {'ул':'улица', 'пл':'площадь','б-р':'бульвар'}
for key,value in vocab.items():
    regions['Тип'] = regions['Тип'].str.replace(key,value)

# %%
regions.head()
# Out:
#   Наименование    Тип  Индекс                 Административный округ  \
# 0
# 1            1    мкр  142793  Новомосковский административный округ
# 2     1 Маевки  аллея  111395       Восточный административный округ
# 3        1 Мая  улица  124365  Зеленоградский административный округ
# 4          1-й    мкр  142784  Новомосковский административный округ
#
#                    Район
# 0
# 1  Десёновское поселение
# 2          район Вешняки
# 3          район Крюково
# 4   Внуковское поселение

# %%
many_objects = data.groupby('streets',as_index=False).agg({'id':'count'})\
.sort_values(by='id', ascending=False)\
.rename(columns={'id':'obj_number'})\
.head(10)\
.reset_index(drop=True)
many_objects.head(10)
# Out:
#                    streets  obj_number
# 0            проспект Мира         203
# 1        Профсоюзная улица         181
# 2   Ленинградский проспект         170
# 3   Пресненская набережная         167
# 4         Варшавское шоссе         163
# 5       Ленинский проспект         147
# 6     проспект Вернадского         128
# 7     Кутузовский проспект         114
# 8          Каширское шоссе         111
# 9     Кировоградская улица         108

# %%
many_objects_copy = many_objects.copy()

# %%
many_objects['streets'] = many_objects['streets'].apply(lambda x: x.strip())

# %%
many_objects['streets'] = many_objects['streets'].replace('проспект Вернадского','Вернадского проспект')

# %%
many_objects['streets'] = many_objects['streets'].replace('проспект Мира','Мира проспект')

# %%
many_objects
# Out:
#                   streets  obj_number
# 0           Мира проспект         203
# 1       Профсоюзная улица         181
# 2  Ленинградский проспект         170
# 3  Пресненская набережная         167
# 4        Варшавское шоссе         163
# 5      Ленинский проспект         147
# 6    Вернадского проспект         128
# 7    Кутузовский проспект         114
# 8         Каширское шоссе         111
# 9    Кировоградская улица         108

# %%
many_objects['street_name'] = many_objects['streets'].apply(lambda x: x.split(' ')[0].strip())

# %%
many_objects
# Out:
#                   streets  obj_number     street_name
# 0           Мира проспект         203            Мира
# 1       Профсоюзная улица         181     Профсоюзная
# 2  Ленинградский проспект         170   Ленинградский
# 3  Пресненская набережная         167     Пресненская
# 4        Варшавское шоссе         163      Варшавское
# 5      Ленинский проспект         147       Ленинский
# 6    Вернадского проспект         128     Вернадского
# 7    Кутузовский проспект         114     Кутузовский
# 8         Каширское шоссе         111       Каширское
# 9    Кировоградская улица         108  Кировоградская

# %%
merged_region = (many_objects.merge(regions[['Административный округ','Район','Наименование']], left_on='street_name',right_on='Наименование',how='left')[['streets','Административный округ','Район']]\
    .rename(columns={'streets':'Улица'})
)
merged_region.drop_duplicates()
# Out:
#                      Улица                   Административный округ  \
# 0            Мира проспект  Северо-Восточный административный округ
# 1            Мира проспект    Новомосковский административный округ
# 2            Мира проспект         Троицкий административный округ
# 3        Профсоюзная улица    Новомосковский административный округ
# 4        Профсоюзная улица      Юго-Западный административный округ
# 5   Ленинградский проспект          Северный административный округ
# 6   Пресненская набережная       Центральный административный округ
# 7         Варшавское шоссе             Южный административный округ
# 8       Ленинский проспект      Юго-Западный административный округ
# 9     Вернадского проспект      Юго-Западный административный округ
# 10    Кутузовский проспект          Западный административный округ
# 13         Каширское шоссе             Южный административный округ
# 14    Кировоградская улица             Южный административный округ
#
# ...

# %%
df = (merged_region.query('~((Район == "Внуковское поселение")or (Район == "Краснопахорское поселение") or (Район == "Рязановское поселение"))')).drop_duplicates()
df
# Out:
#                      Улица                   Административный округ  \
# 0            Мира проспект  Северо-Восточный административный округ
# 4        Профсоюзная улица      Юго-Западный административный округ
# 5   Ленинградский проспект          Северный административный округ
# 6   Пресненская набережная       Центральный административный округ
# 7         Варшавское шоссе             Южный административный округ
# 8       Ленинский проспект      Юго-Западный административный округ
# 9     Вернадского проспект      Юго-Западный административный округ
# 10    Кутузовский проспект          Западный административный округ
# 13         Каширское шоссе             Южный административный округ
# 14    Кировоградская улица             Южный административный округ
#
#                           Район
# 0            Алексеевский район
# 4                район Коньково
# 5             Хорошевский район
# 6             Пресненский район
# 7   район Чертаново Центральное
# ...

# %%
fig = go.Figure(data=[go.Table(
    header=dict(values=list(df.columns),
                fill_color='lavender',
                align='left'),
    cells=dict(values=[df['Улица'], df['Административный округ'], df['Район']],
               fill_color='white',
               align='left'))
])
fig.write_image("/Users/ulia/yandex_DA/Yandex_Practicum_Projects/Data_Analytics/10_Data_Visualization/Images/fig13.jpeg")
fig.show()

# %% [markdown]
# Видим, что "настоящий" густонаселенный и центральный Проспект Мира находится в Алексеевском районе Северо-Восточного округа, и Профсоюзная улица Юго-Западного администативного округа  очень протяженная, поэтому на ней столько заведений. Также к очень проятженным улицам относятся и Ленинский, и Вернадский, и Кутузовский проспекты, а также Каширское шоссе
# В наш список попали не улицы с большой плотностью заведений, а протяженные улицы, с большим их абсолютным количеством.

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <h3>👀 Комментарий ревьюера</h3>
#
# Где же выше Пресненская набережная? :) Проспект Мира не только в центре, это довольно протяженная улица. Тут нижно для каждой улицы вывести все районы, чтобы было явно видно длину каждой улицы
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Улицы и правда протяженные, поэтому концетрация заведений на них может быть невыоской. А есть идеи, как можно найти топ-10 из плотных улиц?</div>

# %% [markdown]
# <div class="alert alert-info" style="background:#ffdbf1;color:#2e00ab;border-left:7px solid #2e00ab">
# <h3> Думаю, можно узнать длину улиц, в Википедии есть, посмотреть количество заведений на 100 м улицы или еще как-то </h3>
#     ...
# </div>

# %% [markdown]
# <a id='three-eight'></a>
# ### 2.8 Найдите число улиц с одним объектом общественного питания. Воспользуйтесь внешней информацией и ответьте на вопрос — в каких районах Москвы находятся эти улицы?

# %%
num_obj = data.groupby('streets',as_index=False)\
    .agg({'id':'count'})\
    .sort_values(by='id', ascending=False)

# %%
one_object = num_obj.query('id==1')['streets'].unique().tolist()

# %%
for word in words:
    print(word)
# Out:
# улица
# деревня
# поселение
# аллея
# бульвар
# линия
# мост
# набережная
# парк
# переулок
# площадь
# посёлок
# проезд
# проектируемый проезд
# просека
# проспект
# тупик
# шоссе

# %%
one_object_lst = [obj.replace('переулок'," ")\
    .replace('улица','')\
    .replace('деревня','')\
    .replace('поселение','')\
    .replace('аллея','')\
    .replace('бульвар','')\
    .replace('линия','')\
    .replace('набережная','')\
    .replace('парк','')\
    .replace('переулок','')\
    .replace('площадь','')\
    .replace('посёлок','')\
    .replace('проектируемый проезд','')\
    .replace('просека','')\
    .replace('проспект','')\
    .replace('тупик','')\
    .replace('шоссе','')\
    .replace('проезд','').strip() for obj in one_object]

# %%
one_object_lst
# Out:
# ['6-я  Новые Сады',
#  '1-й Голутвинский',
#  '7-й Ростовский',
#  'Кошкина',
#  'Земляной Вал',
#  'Добролюбова',
#  '7-я  Лазенки',
#  'Знаменка',
#  '7-я Северная',
#  'Ащеулов',
#  'Алымов',
#  'Захарьинские Дворики',
#  'Аэрофлотская',
#  '6-я  Лазенки',
#  'Обручева',
#  'Базовая',
#  'Кубинка',
#  'Евгения Родионова',
#  '1-й Зачатьевский',
#  '1-й Заречный',
#  '5-й  Подбельского',
#  'Щорса',
#  'Миклухо-Маклая',
#  'Крутицкий Вал',
#  'Бабаевская',
#  '6-я Кожуховская',
#  'Энгельса',
#  'Екатерины Будановой',
#  '1-й Балтийский',
#  '1-й Басманный',
#  'Жебрунова',
#  'Жуковского',
#  'Каманина',
#  'Красных Зорь',
#  '8-й  Марьиной Рощи',
#  'Зенитчиков',
#  '1-й Нагатинский',
#  'Школьная',
#  'Вознесенский',
#  'Вспольный',
#  'Профсоюзная',
#  'Анненская',
#  'Проектируемый  N 5231',
#  'Дербеневская',
#  'Андроньевская',
#  'Калашный',
#  'Клочкова',
#  'Киевская',
#  'Коровинское',
#  'Краснобогатырская',
#  '5-й Рощинский',
#  'Поречная',
#  'Ленинский',
# ...

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Круто, что решила спарсить 👍 310 это число страниц? Чтобы не указывать, можно было бы написать бесконечный цикл и по `HttpError` делать из него возврат (т.е. когда страница не находится)
# </div>

# %% [markdown]
# <div class="alert alert-info" style="background:#ffdbf1;color:#2e00ab;border-left:7px solid #2e00ab">
# <h3> Не поняла, как так делать, подскажи, пожалуйста, где посмотреть</h3>
#     ...
# </div>

# %%
regions_one_object = regions[regions['Наименование'].isin(one_object_lst)]

# %%
regions_one_object
# Out:
#           Наименование      Тип  Индекс  \
# 11      1-й Балтийский      пер  125315
# 12       1-й Басманный      пер
# 15    1-й Ботанический   проезд  129323
# 20    1-й Вешняковский   проезд  109456
# 28    1-й Голутвинский      пер  119180
# ...                ...      ...     ...
# 6482           Яузский  бульвар  109028
# 6483         Яхромская    улица  127411
# 6495       Ясногорская    улица
# 6502           Яузский  бульвар  109028
# 6503         Яхромская    улица  127411
#
#                        Административный округ                 Район
# 11            Северный административный округ        район Аэропорт
# 12         Центральный административный округ  Красносельский район
# 15    Северо-Восточный административный округ        район Свиблово
# 20       Юго-Восточный административный округ       Рязанский район
# 28         Центральный административный округ        район Якиманка
# ...                                       ...                   ...
# ...

# %%
regions_one_object.groupby('Район',as_index=False)\
    .agg({'Наименование':'count'})\
    .sort_values(by='Наименование',ascending=False)\
    .rename(columns={'Наименование':'streets_num', 'Район':'region'}).head(10).reset_index(drop=True)
# Out:
#                       region  streets_num
# 0            Таганский район           34
# 1     Первомайское поселение           29
# 2          Пресненский район           26
# 3            район Хамовники           25
# 4            Басманный район           24
# 5             Тверской район           23
# 6       Внуковское поселение           22
# 7     Марушкинское поселение           21
# 8  Краснопахорское поселение           19
# 9            Мещанский район           18

# %%
regions_one_object.groupby('Административный округ',as_index=False)\
    .agg({'Наименование':'count'})\
    .sort_values(by='Наименование',ascending=False)\
    .rename(columns={'Наименование':'streets_num', 'Административный округ':'district'}).head(10)\
    .reset_index(drop=True)
# Out:
#                                   district  streets_num
# 0       Центральный административный округ          198
# 1    Новомосковский административный округ           98
# 2         Троицкий административный округ            94
# 3  Северо-Восточный административный округ           62
# 4          Северный административный округ           61
# 5         Восточный административный округ           59
# 6     Юго-Восточный административный округ           55
# 7          Западный административный округ           46
# 8             Южный административный округ           38
# 9      Юго-Западный административный округ           31

# %% [markdown]
# Удалось найти 777 улиц с одним заведением общепита
# Большинство таких улиц - в Таганском, Пресненском и Басманном, Хамовническом районах и в поселениях
# Причина скорее всего кроется в невероятно высокой стоимости аренды в центре города
# По округам - лидирует Центральный административный округ и Новая Москва

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Тут всё здорово получилось 👍 Предлагаю этот же датасет использовать для того, чтобы выделить районы для топ-10 улиц. Ну и типов улиц стоит добавить. Чуть аккуратнее было бы для улиц сделать 2 столбца: с наименованием и типом (а не удалять типа) и смержить таблицы по двум столбцам
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
#
# Тут в качестве визуализации хорошо бы подошла тепловая карта. Можно было бы отобразить районы для улиц с 1 завдеением на карте Москвы и цветом показать, где больше всего улиц. Для этого понадобится
#
# - датасет с координатами графниц районов: https://gis-lab.info/qa/moscow-atd.html
#
# - геовизуализация https://plotly.com/python/maps/
#
# Этим можно заняться, если захочется вернуться к проекту или на досуге поиграться
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="background:#ffdbf1;color:#2e00ab;border-left:7px solid #2e00ab">
# <h3> Это наверное очень непросто, я обязательно попробую</h3>
#     ...
# </div>

# %% [markdown]
# <a id='three-nine'></a>
# ### 2.9 Посмотрите на распределение количества посадочных мест для улиц с большим количеством объектов общественного питания.
# Какие закономерности можно выявить?

# %%
many_obj_data = data[data['streets'].isin(many_objects_copy['streets'].tolist())]
many_obj_data.head()
# Out:
#          id      object_name chain object_type  \
# 151  155973  кафе «андерсон»    да        кафе
# 152   23618    кафе «subway»    да        кафе
# 153  155852   кафе «ламаджо»   нет        кафе
# 154  152556    шаурма в пите   нет     фастфуд
# 155  120658          выпечка   нет   кафетерий
#
#                                               address  number  \
# 151             город Москва, Варшавское шоссе, дом 2     150
# 152   город Москва, Варшавское шоссе, дом 7, корпус 1      36
# 153            город Москва, Варшавское шоссе, дом 29      30
# 154  город Москва, Варшавское шоссе, дом 72, корпус 2       0
# 155           город Москва, Варшавское шоссе, дом 100       2
#
#                streets
# 151   Варшавское шоссе
# 152   Варшавское шоссе
# 153   Варшавское шоссе
# 154   Варшавское шоссе
# 155   Варшавское шоссе

# %%
fig = px.histogram(many_obj_data, x='number',labels={'number':'количество посадочных мест'},
title='Распределение посадочных мест по улицам с большим количеством объектов')
fig.write_image("/Users/ulia/yandex_DA/Yandex_Practicum_Projects/Data_Analytics/10_Data_Visualization/Images/fig8.jpeg")
fig.show()

# %% [markdown]
# Видим, что больше всего очень маленьких заведений до 10 мест  - дорогая аренда в центре!

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Чтобы можно было улицы из топ-10 сравнить между собой, можно построить по боксплоту для каждой улицы. А вообще, этого пункта в брифе уже нет :)
# </div>

# %% [markdown]
# <div class="alert alert-info" style="background:#ffdbf1;color:#2e00ab;border-left:7px solid #2e00ab">
# <h3>Почему нужен boxplot для каждой улицы? Где нет? Я же с сайта брала задания</h3>
#     ...
# </div>

# %%
many_obj_data.groupby('object_type',as_index=False)\
    .agg({'id':'count'})\
    .sort_values(by='id',ascending=False)\
    .rename(columns={'id':'objects'})
# Out:
#   object_type  objects
# 3        кафе      632
# 6    ресторан      290
# 8     фастфуд      252
# 7    столовая      137
# 0         бар       63
# 4   кафетерий       47
# 1       буфет       31
# 5   кулинария       24
# 2  закусочная       16

# %% [markdown]
# Как и в целом по городу, на пером месте по количеству заведений - кафе, а вот столовая уступила свои позиции ресторанам и фастфуду. В центре столовые - необычный формат

# %%
fig = px.bar(many_obj_data.groupby('object_type',as_index=False)\
    .agg({'id':'count'})\
    .sort_values(by='id',ascending=False)\
    .rename(columns={'id':'objects'}), x='object_type', y='objects',labels={'object_type':'типы объектов',
    'objects':'количество объектов'},
title='Распределение объектов по типам на улицах с большим количеством заведений')
fig.write_image("/Users/ulia/yandex_DA/Yandex_Practicum_Projects/Data_Analytics/10_Data_Visualization/Images/fig9.jpeg")
fig.show()

# %%
fig = px.box(many_obj_data, y='number', x='object_type',title='Посадочные места на улицах с болшим количеством объектов', 
    labels={'object_type':'Тип объекта', 'number':'количество мест'})
fig.update_layout(yaxis_range=[0,250])
fig.write_image("/Users/ulia/yandex_DA/Yandex_Practicum_Projects/Data_Analytics/10_Data_Visualization/Images/fig10.jpeg")
fig.show()

# %%
fig = px.density_heatmap(many_obj_data, x="object_type", y="streets", 
title='Распределение типов заведений по улицам',
labels={'object_type':'типы объектов','streets':'улицы'})
fig.write_image("/Users/ulia/yandex_DA/Yandex_Practicum_Projects/Data_Analytics/10_Data_Visualization/Images/fig11.jpeg")
fig.show()

# %% [markdown]
# Больше всего кафе на Пресненской набережной, Профсоюзной улице и проспекте Мира - около 100!

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Тут удачно было построить хитмап, где по вертикали были бы улицы, а по горизонтали доля заведений каждого типа
# </div>

# %% [markdown]
# <a id='Conclusion'></a>
# ## 3. Общий вывод
# ### Сделайте общий вывод и дайте рекомендации о виде заведения, количестве посадочных мест, а также районе расположения. Прокомментируйте возможность развития сети.

# %% [markdown]
# ## В наших планах - открыть оригинальное заведение, которое потребует больших инвестиций, судя по проведенному анализу рынка, стоит открыть кафе - с небольшим количеством мест  - около 30 в одном из центральных районов города - Центральном, Юго-Западном

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <h3>👀 Комментарий ревьюера</h3>
#
#
# А почему до 10? Это буквально 2 стола.
#
# > в одном из самых проходимых мест города.
#
# Это здорово, но совсем неконкретно :) Лучше указать конкретные район/улицу
#
# </div>

# %% [markdown]
# <div class="alert alert-success" ; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Если интересно, то используя геокодер (или датасет с координитами для адресов) и геовизуализацию можно построить распределение кафе на территории Москвы и выделить интересующие нас районы, затем в этих районах можно отобразить доступные площащи для аренды, спарсив какой-нибудь сайт объявлений и таким образом выбрать нужное местоположение. https://geocoder.readthedocs.io/ + https://python-visualization.github.io/folium/quickstart.html. Этим можно заняться, если захочется вернуться к проекту
#
#
# Нелохая преза, круто что к каждому графику есть вывод, но всё же стоит его оформлять отдельно, а не в заголовке слайда. А в заголовке писать то, о чём слайд.  Можно также добавить слайд с постановкой задач, чтобы к концу презентации было понятно, что все цели и задачи были достигнуты и выполнены, и в целом слайд с введением всегда полезен. Чтобы из таблички получить картинку, можно пользоваться https://plotly.com/python/table/ Графики стоит сохрпанять через `plt.savefig` для `pyplot` и https://plotly.com/python/static-image-export/ для `plotly`, чтобы качество не терялось. Часто бывает удобно слайды нумеровать.
#
# Для през могу порекомендовать сервис https://readymag.com/. Там много всяких визуальных элементов и можно включать кучу сеток, чтобы выравнивать контент по слайдам или вот ещё классный есть: https://www.canva.com/ru_ru/
#
#
# Здорово, что загружаешь на гитхаб, но там есть определенные правила с этим. Например, формулировки заданий нужно переписывать своими словами. Можно у куратора на эту тему попросить методичку, где-то я такую видел, но сходу не найду. Также вероятно лучше без комментария ревьюера выкладывать проекты. Если ты используешь репозиторий чисто для контроля версий, то тогда его можно сделать приватным. Ещё я у тебя пару форков увидел. Репозиторий обычно форкают, чтобы туда сделать пулл-реквест. Если хочется таким образом добавить репозиторий в избранное, то можно просто у репозитория нажать на звёздочку справа вверху.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="background:#ffdbf1;color:#2e00ab;border-left:7px solid #2e00ab">
# <h3>readymag - очень крутая штука, но мне нужно в ней разобраться, пока сделаю в keynote</h3>

# %% [markdown]
# <div class="alert alert-info" style="background:#ffdbf1;color:#2e00ab;border-left:7px solid #2e00ab">
# <h3>Большое спасибо за комментарии, про git - я только недавно стала им активно пользоваться и буквально вчера залила туда проекты, наверное надо их очищать от комменатриев, ты прав,  у меня по git к тебе вопрос: как сделать так, чтобы оглавление (ссылки на пункты) внутри гита работали?  Если мне нужны проекты для англоязычной аудитории, их надо переводить? прямо целиком? Спасибо!</h3>
#     ...
# </div>

# %% [markdown]
# ## Презентация
# [Презентация](https://github.com/kbzunder/Yandex_Practicum_Projects/blob/main/Data_Analytics/10_Data_Visualization/Presentation.pdf)
