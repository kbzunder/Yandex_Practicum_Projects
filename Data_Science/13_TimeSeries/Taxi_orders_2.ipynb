# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Юлия, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам аналитика. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Критичные ошибки, которые обязательно нужно исправить.
# </div>
#
# Я не смогу принять проект, если в нём будет хотя бы одна критичная ошибка или несколько некритичных ошибок - тогда проект нужно будет немного доработать. Но это нестрашно - я обязательно дам тебе подсказку или укажу верное направление.
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <br/>
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# # Прогнозирование заказов такси
# Для компании, работающей в аэропортах, необходимо предсказать количество заказов такси на следующий час, имея в распоряжении исторические данные

# %% [markdown]
# [1. Загрузка данных](#data_download)
# [2. Знакомство в с данными. Предобработка](#data_preprocessing)
# [3. Feature engeneering](#feature_engeneering)
# [4. Выбор модели, обучение, предсказание](#ml_process)
# [5. Выводы](#Conclusion)

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Неплохое вступление!
#
# Задали старт для возможности понять суть проекта с первых строк отчёта!
#
# Спасибо, что сделала оглавление в виде гиперссылок - по проекту удобно перемещаться! Ещё более удобным было бы оглавление в плагине toc - материал об этом есть в блоке курса Полезные инструкции для учёбы - Оформление проекта - Изменения в Jupyter: автоматическое оглавление и горячие клавиши. Попробуем?:)

# %% [markdown]
# Я работаю в VSCode, не нашла, что можно из него добавить nbextentions (то есть они загрузились, но не появились)
#
# Не подскажешь, как сделать так, чтобы в гите гиперссылки работали внутри ноутбука? они остаются кликабельными, но ведут из документа, к сожалению

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Вступление к твоему проекту станет намного лучше, если добавить в него задачи проекта (здесь это могут быть шаги проекта из описания в тренажёре), а также описание данных.
#
# </div>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

import os

import matplotlib.pyplot as plt

import lightgbm as lgb

import numpy as np

import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)

from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LinearRegression
from statsmodels.tsa.stattools import adfuller


from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly import graph_objs as go
init_notebook_mode(connected = True)

def plotly_df(df, title = ''):
    data = []
    
    for column in df.columns:
        trace = go.Scatter(
            x = df.index,
            y = df[column],
            mode = 'lines',
            name = column
        )
        data.append(trace)
    
    layout = dict(title = title)
    fig = dict(data = data, layout = layout)
    iplot(fig, show_link=False)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Я вижу, что ячейки в твоей тетрадке начинаются не с 1. Перед отправкой проекта стоит проверять работоспособность кода — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All`` (см скриншот ниже).
#
# ![](https://i.postimg.cc/yd19rYf6/Screenshot-428.png)
#
# В рамках ревью я перезапустил ядро и исполнил код тетрадки, и исполнение прерывалось дважды из-за недостающих модулей `sklearn` - какие-то модули, используемые в проекте, не были помещены в блок импорта. Я поправил эти ошибки, но  в следующий раз, пожалуйста, используй перезапуск, чтобы заранее отсеять такие ошибки:)
# </div>

# %% [markdown]
# <a id='data_download'></a>
# ### 1. Загрузка данных

# %%
#загрузим данные
try:
    data = pd.read_csv('/Users/ulia/Downloads/taxi.csv', index_col=[0], parse_dates=[0])
except FileNotFoundError:
    data = pd.read_csv('/datasets/taxi.csv', index_col=[0], parse_dates=[0])

# %%
path1 = '/Users/ulia/Downloads/taxi.csv'
path2 = '/datasets/taxi.csv'
if os.path.exists(path1):
    data = pd.read_csv(path1, index_col=[0], parse_dates=[0])
elif os.path.exists(path2):
    data = pd.read_csv(path2, index_col=[0], parse_dates=[0])
else: print("ERROR")

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Данные загрузили - отлично! Классно, что сразу парсишь дату и задаёшь столбец с индексами:)
#
# Здорово, что ты используешь конструкцию ``try-except`` для путей файлов. Но еще лучше использовать библиотеку ``os``:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# </div>

# %%
data.head()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32

# %%
plotly_df(data, title = "First glance")
# Out:
# <div>                            <div id="a48edf0a-ce01-44f2-8c74-ce6647cf5670" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a48edf0a-ce01-44f2-8c74-ce6647cf5670")) {                    Plotly.newPlot(                        "a48edf0a-ce01-44f2-8c74-ce6647cf5670",                        [{"mode":"lines","name":"num_orders","x":["2018-03-01T00:00:00","2018-03-01T00:10:00","2018-03-01T00:20:00","2018-03-01T00:30:00","2018-03-01T00:40:00","2018-03-01T00:50:00","2018-03-01T01:00:00","2018-03-01T01:10:00","2018-03-01T01:20:00","2018-03-01T01:30:00","2018-03-01T01:40:00","2018-03-01T01:50:00","2018-03-01T02:00:00","2018-03-01T02:10:00","2018-03-01T02:20:00","2018-03-01T02:30:00","2018-03-01T02:40:00","2018-03-01T02:50:00","2018-03-01T03:00:00","2018-03
# ...

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# Визуализировали исходный временной ряд - отлично! Какие выводы можно сделать из графика?
#
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %%
(data.index.min(), data.index.max())
# Out:
# (Timestamp('2018-03-01 00:00:00'), Timestamp('2018-08-31 23:50:00'))

# %% [markdown]
# В датасете представлены данные с 1 марта по 31 августа 2018 года
# Пропусков нет

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Первый взгляд на данные получился хорошим!
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Здесь заканчивается стрктурный блок работы - стоит делать промежуточные выводы о проделанной работе, это довольно полезная практика, которая имеет большую ценность для получателя отчёта.
#
# Достаточно будет двух-трёх тезисных предложений об основных шагах и полученных выводах.
#
# </div>

# %% [markdown]
# ### Промеждуточные итоги:
# * Загрузили данные
# * Выяснили, что представлена информация о заказах такси с интервалом в 10 минут с марта по август 2018 года
# * Пропуски в данных отстуствуют

# %% [markdown]
# <a id='data_preprocessing'></a>
# ### 2. Знакомство в с данными. Предобработка

# %%
# У нас даны данные с интервалом в 10 минут , сгруппируем данные по часу:

data = data.resample('1H').sum()
plotly_df(data, 'Данные после resampling')
# Out:
# <div>                            <div id="2c48c8ca-fbc9-4dc3-842c-3234a626d6af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c48c8ca-fbc9-4dc3-842c-3234a626d6af")) {                    Plotly.newPlot(                        "2c48c8ca-fbc9-4dc3-842c-3234a626d6af",                        [{"mode":"lines","name":"num_orders","x":["2018-03-01T00:00:00","2018-03-01T01:00:00","2018-03-01T02:00:00","2018-03-01T03:00:00","2018-03-01T04:00:00","2018-03-01T05:00:00","2018-03-01T06:00:00","2018-03-01T07:00:00","2018-03-01T08:00:00","2018-03-01T09:00:00","2018-03-01T10:00:00","2018-03-01T11:00:00","2018-03-01T12:00:00","2018-03-01T13:00:00","2018-03-01T14:00:00","2018-03-01T15:00:00","2018-03-01T16:00:00","2018-03-01T17:00:00","2018-03-01T18:00:00","2018-03
# ...

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Сделали ресэмплирование по 1 часу и применили суммирование как агрегационную функцию - отлично, самое верное решение с точки зрения интерпретации результатов.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Перед ресэмплированием стоит проверить, монотонно ли возрастают временнЫе индесы с помощью метода `.is_monotonic`.
# </div>

# %%
#Проверим на монотонность
data.index.is_monotonic
# Out:
# True

# %% [markdown]
# Данные монотонны, без пропусков

# %% [markdown]
# После увеличения на графике хорошо видны тренды и сезонность, также выделяются пики в августе

# %%
data.head()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00         124
# 2018-03-01 01:00:00          85
# 2018-03-01 02:00:00          71
# 2018-03-01 03:00:00          66
# 2018-03-01 04:00:00          43

# %%
#Декомпозируем данные, выделим сезонность
decomposed = seasonal_decompose(data)

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Декомпозировали временной ряд на составляющие - хорошо!
# </div>

# %%
seasonal = pd.DataFrame(decomposed.seasonal)
plotly_df(seasonal['2018-08-01':'2018-08-31'], 'Сезонность')
# Out:
# <div>                            <div id="26b7e7aa-188a-4265-9940-d323507eb26e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26b7e7aa-188a-4265-9940-d323507eb26e")) {                    Plotly.newPlot(                        "26b7e7aa-188a-4265-9940-d323507eb26e",                        [{"mode":"lines","name":"seasonal","x":["2018-08-01T00:00:00","2018-08-01T01:00:00","2018-08-01T02:00:00","2018-08-01T03:00:00","2018-08-01T04:00:00","2018-08-01T05:00:00","2018-08-01T06:00:00","2018-08-01T07:00:00","2018-08-01T08:00:00","2018-08-01T09:00:00","2018-08-01T10:00:00","2018-08-01T11:00:00","2018-08-01T12:00:00","2018-08-01T13:00:00","2018-08-01T14:00:00","2018-08-01T15:00:00","2018-08-01T16:00:00","2018-08-01T17:00:00","2018-08-01T18:00:00","2018-08-0
# ...

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Визуализировали сезонную компоненту - хорошо!
# </div>

# %%
plotly_df(seasonal['2018-08-29':'2018-08-31'], 'Сезонность в рамках дней')
# Out:
# <div>                            <div id="eefe40db-6c4b-4484-b7b7-9fe9e4a0030c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eefe40db-6c4b-4484-b7b7-9fe9e4a0030c")) {                    Plotly.newPlot(                        "eefe40db-6c4b-4484-b7b7-9fe9e4a0030c",                        [{"mode":"lines","name":"seasonal","x":["2018-08-29T00:00:00","2018-08-29T01:00:00","2018-08-29T02:00:00","2018-08-29T03:00:00","2018-08-29T04:00:00","2018-08-29T05:00:00","2018-08-29T06:00:00","2018-08-29T07:00:00","2018-08-29T08:00:00","2018-08-29T09:00:00","2018-08-29T10:00:00","2018-08-29T11:00:00","2018-08-29T12:00:00","2018-08-29T13:00:00","2018-08-29T14:00:00","2018-08-29T15:00:00","2018-08-29T16:00:00","2018-08-29T17:00:00","2018-08-29T18:00:00","2018-08-2
# ...

# %% [markdown]
# Удалось выделить сезонность - больше всего заказов в полночь - потом локальные пики в 10 и 16 часов, провал - в районе 6 часов утра

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Проанализировали сезонность на коротком промежутке времени для понимания её природы и характерных признаков - отлично!
#
# Как думаешь, чем данная сезонность может быть обусловлена?
# </div>

# %% [markdown]
# Ночью пик может быть вызван тем, что другим транспортом добраться до места сложно, в 16 часов еще нет вечерних пробок? Трудно сказать, с чем связана такая сезонность

# %%
trend = pd.DataFrame(decomposed.trend)
plotly_df(trend, 'Тренд')
# Out:
# <div>                            <div id="a28fa20c-5438-4ab9-b386-7f73fcc730cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a28fa20c-5438-4ab9-b386-7f73fcc730cb")) {                    Plotly.newPlot(                        "a28fa20c-5438-4ab9-b386-7f73fcc730cb",                        [{"mode":"lines","name":"trend","x":["2018-03-01T00:00:00","2018-03-01T01:00:00","2018-03-01T02:00:00","2018-03-01T03:00:00","2018-03-01T04:00:00","2018-03-01T05:00:00","2018-03-01T06:00:00","2018-03-01T07:00:00","2018-03-01T08:00:00","2018-03-01T09:00:00","2018-03-01T10:00:00","2018-03-01T11:00:00","2018-03-01T12:00:00","2018-03-01T13:00:00","2018-03-01T14:00:00","2018-03-01T15:00:00","2018-03-01T16:00:00","2018-03-01T17:00:00","2018-03-01T18:00:00","2018-03-01T1
# ...

# %% [markdown]
# Наблюдаем положительный тренд, число заказов постоянно растет с марта до августа

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Действительно, тренд говорит о постоянном увеличении количества заказов с весны по конец лета? Как думаешь, почему так происходит в контекте природы наших данных?
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Дополнительно стоит оценить стационарность ряда и сделать об этом вывод. Сделать это можно с помощью сглаживания скользящим средним и последующей визуализацией сглаженного ряда на графике - это самый простой способ, и в рамках проекта этот способ допустим. В реальных же задачах с временными рядами, в особенности - с финансовыми данными или биржевыми котировками, график не всегда поможет достоверно оценить стационарность ряда. Поэтому для оценки стационарности ряда лучше использовать тест Дики — Фуллера (подробнее о нём можно глянуть тут: https://www.statsmodels.org/dev/generated/statsmodels.tsa.stattools.adfuller.html) - он даст наиболее точный результат. Если попробуешь оба способа - будет здорово:)
# </div>

# %%
## Попробуем применить скользящее среднее для оценки стационарности временного ряда:
stationar = data.resample('1D').sum().rolling(30).mean()

# %%
plotly_df(stationar, 'Сглаживание')
# Out:
# <div>                            <div id="f84fc1f3-3c3c-499d-8b12-2c6822823cc4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f84fc1f3-3c3c-499d-8b12-2c6822823cc4")) {                    Plotly.newPlot(                        "f84fc1f3-3c3c-499d-8b12-2c6822823cc4",                        [{"mode":"lines","name":"num_orders","x":["2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-03T00:00:00","2018-03-04T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-10T00:00:00","2018-03-11T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-17T00:00:00","2018-03-18T00:00:00","2018-03-19T00:00:00","2018-03
# ...

# %% [markdown]
# Среднее такого ряда не постоянно - ряд не стационарный

# %%
# Применим тест Дики-Фулера
# H0 - ряд не стационарный
# H1 - ряд  стационарны
adful = adfuller(data.values)
print(adful[0])
# Out:
# -3.068924289027937

# %%
print('P-Value: ', adful[1])
# Out:
# P-Value:  0.028940051402614374

# %%
print('Critical values:')
for key, value in adful[4].items():
	print('{}: {:.2f}'.format(key, value))
# Out:
# Critical values:
# 1%: -3.43
# 5%: -2.86
# 10%: -2.57

# %% [markdown]
# По нашим данным, если мы принимаем уровень значимости за 5%, то мы можем отвергнуть нулевую гипотезу, значит имеем стационарный процесс, что странно
#
# Если принимаем уровень значимости за 1%, то можем отвергнуть нулевую гипотезу и имеем нестационарный процесс

# %% [markdown]
# Зачем в рамках данного проекта проверять ряд на стационарность? Мы же это потом нигде не используем?
# У нас виден явный положительный тренд, разве может быть такой ряд стационарным? Зачем проверять другими методами?

# %% [markdown]
# ### Промеждуточные итоги:
# * Провели ресемплирование данных по 1 часу
# * Декомпозировали временной ряд, выделили тренд и сезонность
# * Проверили ряд на стационарность. Я читаю, что у нас нестационарный временной ряд

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Здесь заканчивается стрктурный блок работы - стоит сделать промежуточные выводы о проделанной работе в блоке.

# %% [markdown]
# <a id='feature_engeneering'></a>
# ### 3. Feature engeneering

# %%
def code_mean(data, cat_features, real_feature):
    return dict(data.groupby(cat_features)[real_feature].mean())

# %%
def prepare_data(data, lags, test_size=0.1):
    df = pd.DataFrame(data.copy())
    df.columns = ['y']
    
    test_index = int(len(data)*(1-test_size))

    #добавляем лаги
    for lag in lags:
        df['lag_{}'.format(lag)] = df.y.shift(lag)


    #data.index = data.index.to_datetime()
    df['hour'] = df.index.hour
    df['weekday'] = df.index.weekday
    df['is_weekend']= df.weekday.isin([5,6])*1

    df['weekday_average'] = list(map(code_mean(df[:test_index],'weekday','y').get, df.weekday))
    df['hour_average'] = list(map(code_mean(df[:test_index],'hour','y').get, df.hour))
    
    df.drop(['hour','weekday'], axis=1, inplace=True)
    
    # удалим строки с пропусками
    df = df.dropna()
    df = df.reset_index(drop=True)
    
    #разбиваем на тренировочную, тестовую и валидационную выборки:
    features = df.drop('y', axis=1)
    target = df['y']



    features_train_full, features_test, target_train_full, target_test = train_test_split(features, target, test_size=test_size, shuffle=False)
    
    features_train, features_valid, target_train, target_valid = train_test_split(features_train_full, target_train_full, test_size=test_size,shuffle=False)
    return features_train, features_valid, features_test, target_train, target_valid, target_test

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Интересное решение по предобарботке данных - несколько стуктурных блоков реализованы в одной функции - неплохо!

# %%
features_train, features_valid, features_test, target_train, target_valid, target_test = prepare_data(data, [1,2,3,4,5,6,7], 0.1)

# %%
(features_train.index.max(), features_valid.index.min())
# Out:
# (3570, 3571)

# %%
(features_valid.index.max(), features_test.index.min())
# Out:
# (3967, 3968)

# %% [markdown]
# Разбиение на выборки выполнено корректно

# %%
features_train.head()
# Out:
#    lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7  is_weekend  \
# 0   12.0    6.0   43.0   66.0   71.0   85.0  124.0           0
# 1   15.0   12.0    6.0   43.0   66.0   71.0   85.0           0
# 2   34.0   15.0   12.0    6.0   43.0   66.0   71.0           0
# 3   69.0   34.0   15.0   12.0    6.0   43.0   66.0           0
# 4   64.0   69.0   34.0   15.0   12.0    6.0   43.0           0
#
#    weekday_average  hour_average
# 0        78.276042     27.439759
# 1        78.276042     68.228916
# 2        78.276042     81.602410
# 3        78.276042     86.253012
# 4        78.276042     77.102410

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Интересное решение по предобарботке данных - несколько стуктурных блоков реализованы в одной функции - неплохо!
#
# Сплитование сделано корректно как с точки зрения учёта специфики временного ряда (отключено перемешивание), так и размера тестовой выборки. Также выделили признаки для обучения и целевой признак - хорошо!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Здесь заканчивается стрктурный блок работы - стоит сделать промежуточные выводы о проделанной работе в блоке.

# %% [markdown]
# ### Промеждуточные итоги:
# * Добавили новые метрики (лаги, средние заказы за день, категориальную переменную - is_weekend)
# * Разделили данные на тренировочную, валидационную и тестовую выборки

# %% [markdown]
# <a id='ml_process'></a>
# ### 4. Выбор модели, обучение, предсказание

# %%
numeric = list(features_train.columns)

# %%
numeric.remove('is_weekend')

# %%
numeric
# Out:
# ['lag_1',
#  'lag_2',
#  'lag_3',
#  'lag_4',
#  'lag_5',
#  'lag_6',
#  'lag_7',
#  'weekday_average',
#  'hour_average']

# %%
# нормализуем данные:
scaler = StandardScaler()
features_train[numeric] = scaler.fit_transform(features_train[numeric])
features_valid[numeric] = scaler.transform(features_valid[numeric])
features_test[numeric] = scaler.transform(features_test[numeric])

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выполнили шкалирование - неплохой шаг!
# </div>

# %%
# обучим модель линейной регрессии
reg_model = LinearRegression()
reg_model.fit(features_train, target_train)
predictions_reg = reg_model.predict(features_valid)
MSE_reg = mean_squared_error(predictions_reg, target_valid, squared=False)

# %%
print('Значение RMSE на линейной регрессии {:.2f}'.format(MSE_reg))
# Out:
# Значение RMSE на линейной регрессии 35.75

# %%
plt.figure(figsize=(15, 7))
plt.plot(predictions_reg, "r", label="prediction")
plt.plot(target_valid.values, label="actual")
plt.legend(loc="best")
plt.title("Linear regression\n RMSE {}".format(round(MSE_reg)))
plt.grid(True)

# %% [markdown]
# Хотя RMSE ниже порога в 48 единиц, трудно сказать, что предсказание очень хорошее

# %%
RMSE_reg_test = mean_squared_error(reg_model.predict(features_test), target_test, squared=False)

# %%
RMSE_reg_test
print('Значение линейной регрессии на тестовой выборке {:.2f}'.format(RMSE_reg_test))
# Out:
# Значение линейной регрессии на тестовой выборке 52.48

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Обучили линейную регрессию на тренировочных данных, протестировали на валидации и тесте, сделали график сравнения реальных и предсказанных значений - хорошо! Трешхолд всё ещё не преодолели, но мы только начинаем:)
# </div>

# %%
#Попробуем разное количество лагов для модели:
def test_reg_model(lags):
    res = {}
    for i in list(range(3, lags+1)):
        features_train, features_valid, features_test, target_train, target_valid, target_test = prepare_data(data, list(range(1,i+1)), 0.1)
        numeric = list(features_train.columns)
        numeric.remove('is_weekend')
        scaler = StandardScaler()
        features_train[numeric] = scaler.fit_transform(features_train[numeric])
        features_valid[numeric] = scaler.transform(features_valid[numeric])
        features_test[numeric] = scaler.transform(features_test[numeric])
        reg_model = LinearRegression()
        reg_model.fit(features_train, target_train)
        predictions_reg_valid = reg_model.predict(features_valid)
        predictions_reg_test = reg_model.predict(features_test)
        MSE_reg = mean_squared_error(predictions_reg_valid, target_valid, squared=False)       
        MSE_test = mean_squared_error(predictions_reg_test, target_test, squared=False)
        res['lags: {}'.format(i)] = MSE_test
    return res

# %%
test_reg_model(30)
# Out:
# {'lags: 3': 59.15549569390647,
#  'lags: 4': 57.811919504899095,
#  'lags: 5': 56.15110048714092,
#  'lags: 6': 54.750221920128396,
#  'lags: 7': 52.48201226718072,
#  'lags: 8': 51.23318528296898,
#  'lags: 9': 50.550953675482276,
#  'lags: 10': 49.839349457947904,
#  'lags: 11': 48.34649425044382,
#  'lags: 12': 47.490744288490944,
#  'lags: 13': 47.01683242698369,
#  'lags: 14': 46.77462590621825,
#  'lags: 15': 46.414531056199735,
#  'lags: 16': 45.82690001250727,
#  'lags: 17': 45.381034288310055,
#  'lags: 18': 45.33895866280016,
#  'lags: 19': 45.34789010311545,
#  'lags: 20': 45.040320227210984,
#  'lags: 21': 44.91025845708223,
#  'lags: 22': 44.3004381974253,
#  'lags: 23': 43.90073963727054,
#  'lags: 24': 43.10976400559981,
#  'lags: 25': 43.43678550295133,
#  'lags: 26': 43.797000608202254,
#  'lags: 27': 43.66370325841717,
#  'lags: 28': 43.71255313191723,
#  'lags: 29': 43.64009535238467,
#  'lags: 30': 43.6547115817263}

# %% [markdown]
# Видим, что при учете 30  предыдущих точек данных, получили модель с ошибкой RMSE 43.7 - ниже нашего трешхолда в 48 единиц

# %%
min_lag = min(test_reg_model(30), key=test_reg_model(30).get)

# %%
min_lag
# Out:
# 'lags: 24'

# %% [markdown]
# Лучше всего учитывать 24 предыдующих шага

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Экспериментально подобрали оптимальное количество окна для лаговых переменных - хорошо! Удалось побить трешхолд проекта!
# </div>

# %% [markdown]
# Попробуем другую модель - LigthGBM

# %%
#LightGBM
# попробуем применить optuna 
from optuna.integration import LightGBMPruningCallback
def objective(trial, features, target):
    param_grid = { 
        "n_estimators": trial.suggest_categorical("n_estimators", [100]),
        "num_leaves": trial.suggest_int("num_leaves", 2, 20, step=1),
        "max_depth": trial.suggest_int("max_depth", 5, 50),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3)
        }
    model = lgb.LGBMRegressor(**param_grid)
    model.fit(features_train, target_train, eval_set=[(features_valid, target_valid)],
    eval_metric='rmse')
    preds = model.predict(features_valid)
    rmse =  mean_squared_error(preds, target_valid, squared=False)
    return rmse

study =optuna.create_study(direction='minimize')
func = lambda trial: objective(trial, features_train, target_train)
study.optimize(func, n_trials=20)
# Out:
# [1]	valid_0's rmse: 57.1398	valid_0's l2: 3264.95
# [2]	valid_0's rmse: 56.3914	valid_0's l2: 3179.99
# [3]	valid_0's rmse: 55.7044	valid_0's l2: 3102.98
# [4]	valid_0's rmse: 55.0178	valid_0's l2: 3026.96
# [5]	valid_0's rmse: 54.3838	valid_0's l2: 2957.59
# [6]	valid_0's rmse: 53.763	valid_0's l2: 2890.46
# [7]	valid_0's rmse: 53.118	valid_0's l2: 2821.53
# [8]	valid_0's rmse: 52.5081	valid_0's l2: 2757.1
# [9]	valid_0's rmse: 51.8992	valid_0's l2: 2693.53
# [10]	valid_0's rmse: 51.3336	valid_0's l2: 2635.14
# [11]	valid_0's rmse: 50.7843	valid_0's l2: 2579.04
# [12]	valid_0's rmse: 50.1743	valid_0's l2: 2517.46
# [13]	valid_0's rmse: 49.6147	valid_0's l2: 2461.62
# [14]	valid_0's rmse: 49.0821	valid_0's l2: 2409.06
# [15]	valid_0's rmse: 48.5604	valid_0's l2: 2358.11
# [16]	valid_0's rmse: 48.0353	valid_0's l2: 2307.39
# [17]	valid_0's rmse: 47.5608	valid_0's l2: 2262.03
# [18]	valid_0's rmse: 47.0974	valid_0's l2: 2218.16
# [19]	valid_0's rmse: 46.6104	valid_0's l2: 2172.53
# ...

# %%
print(f"\tBest value (rmse): {study.best_value:.2f}")
print(f"\tBest params:")

for key, value in study.best_params.items():
    print(f"\t\t{key}: {value}")
# Out:
# 	Best value (rmse): 32.42
# 	Best params:
# 		n_estimators: 100
# 		num_leaves: 5
# 		max_depth: 50
# 		learning_rate: 0.2450182686922776

# %% [markdown]
# С помощью LightGBM получили хорошие данные на валидационной выборке, проверим на тесте

# %%
estimators = list(np.arange(50,500,50))
leaves = [2,3,4,7,9,12,14,16,18]
max_depth = list(np.arange(5,50,5))

# %%
for a, b, c in zip(estimators, leaves, max_depth):
    model = lgb.LGBMRegressor(n_estimators=a, num_leaves=b, max_depth=c)
    model.fit(features_train,target_train)
    pred_lbm = model.predict(features_valid)
    RMSE_LBM_valid = mean_squared_error(pred_lbm, target_valid, squared=False)
    print('RMSE на валидационной выборке по LBM {:.2f},esitmators: {}, leaves: {}, max_depth: {}'.format(RMSE_LBM_valid,a,b,c))
# Out:
# RMSE на валидационной выборке по LBM 42.38,esitmators: 50, leaves: 2, max_depth: 5
# RMSE на валидационной выборке по LBM 34.14,esitmators: 100, leaves: 3, max_depth: 10
# RMSE на валидационной выборке по LBM 33.24,esitmators: 150, leaves: 4, max_depth: 15
# RMSE на валидационной выборке по LBM 32.89,esitmators: 200, leaves: 7, max_depth: 20
# RMSE на валидационной выборке по LBM 33.14,esitmators: 250, leaves: 9, max_depth: 25
# RMSE на валидационной выборке по LBM 32.98,esitmators: 300, leaves: 12, max_depth: 30
# RMSE на валидационной выборке по LBM 33.02,esitmators: 350, leaves: 14, max_depth: 35
# RMSE на валидационной выборке по LBM 33.15,esitmators: 400, leaves: 16, max_depth: 40
# RMSE на валидационной выборке по LBM 33.00,esitmators: 450, leaves: 18, max_depth: 45

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Интересно реализован подбор параметров для LightGBM, но всё работает - окей:)
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Реализация твоего перебора параметров напоминает `GridSearchCV` (https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html). Тут уже многое готово из коробки, на будущее стоит познакомиться с этим инструментом и пользоваться при решении табличных задачек - это одна из составляющих успеха:)
#
# Также конкретно в случае `LightGBM` важным параметром модели является `learning_rate`. Его тоже стоило бы перебрать, возможно, результат был бы лучше.

# %% [markdown]
# У Ligth GBM лучший результат, протестируем его на тестовой выборке:

# %%
model_lbm_test = lgb.LGBMRegressor(n_estimators=100, num_leaves=5, max_depth= 50, learning_rate=0.245)
model_lbm_test.fit(features_train, target_train)
pred_test = model_lbm_test.predict(features_test)
RMSE_LBM_test = mean_squared_error(pred_test, target_test, squared=False)
print('RMSE на тестовой выборке по LBM {:.2f}'.format(RMSE_LBM_test))
# Out:
# RMSE на тестовой выборке по LBM 47.02

# %% [markdown]
# Мы получили значение RMSE по тестовой выборке такое же как у линейной регрессии немного ниже трешхолда

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Протестировали LightGBM - хорошо, но трешхолд не побили:)
# </div>

# %%
test = pd.DataFrame(pred_test).reset_index(drop=True)
test.columns = ['orders']
targ = pd.DataFrame(target_test).reset_index(drop=True)
targ.columns = ['orders']

# %%
plt.figure(figsize=(10,7))
plt.plot(test.tail(30), label = 'Preciction')
plt.plot(targ.tail(30),label = 'Actutal')
plt.title('Актуальные данные / предсказания')
plt.xlabel('Наблюдения')
plt.ylabel('Заказы')
plt.legend();

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Над визуализацией стоит чуть поработать:
# 1. Стоит подписать названия осей X и Y.
# 2. Также стоит дать название графику.
# 3. Технические комментарии типа `<matplotlib.legend.Legend at 0x7f706d3317c0>` стоит убирать: это можно сделать, поставив точку с запятой в последней строке кода в блоке визуализации, либо сделать последней строкой кода этого блока метод `plt.show()`.
# 4. Стоит оптимизировать график по размеру: можно немного убавить высоты (конкретно вот этот, остальные в порядке).
#
# Несколько таких нехитрых приёмов очень повысят ценность твоей визуализации:)
#
# Будет здорово, если ты учтёшь эти комментарии для всех графиков в твоей работе.
# </div>

# %% [markdown]
# Предсказания трудно назвать хорошими, но мы укладываемся в ограничения

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Действительно, модель что-то совсем не вывезла:)
#
# Чтобы это исправить, можно сделать пару фокусов:
# 1. Учесть результаты перебора количества лагов в итоговом наборе данных: твоим оптимальным значением по итогу перебора было 30 шагов, а в наборе данных, с которым работают модели, всего 7. Это очень повысит качество модели:)
# 2. Как признак модели стоит также добавить ряд, сглаженный скользящим срденим, а также сезонную компоненту из декомпозированного ряда.
# 3. При переборе параметров для LightGBM также добавить в сетку параметров `learning_rate`.
# 4. Использовать `GridSearchCV` для подбора параметров. Он проводит внутреннюю валидацию самостоятельно, поэтому при его использовании дополнительно выделять валидационную выборку не требуется - стоит передать ему только тренировочную, а выборку для валидации он сам отщипён от неё. Также стоит быть осторожным при кросс-валиации: по умолчанию `GridSearchCV` использует стандартную кросс-валидацию `k-folds`, при которой данные в фолдах перемешиваются, что критично для задач временных рядом. Поэтому нужно использовать кросс-валидацию `TimeSeriesSplit` (https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html).
#
# Это рекомендации - формально твоя модель линейной регрессии достигла трешхолда, и дальше можно не улучшать, но можно сделать решение лучше, следуя рекомендациям. Выбор оставлю за тобой:)
# </div>

# %% [markdown]
# <a id='Conclusion'></a>
# ### 5. Выводы

# %% [markdown]
# 1. Рассмотрели временной ряд заказов такси с марта по август 2018 года
# 2. Выявили сезонность в течение дня, и положительный тренд
# 3. В конце августа заметили аномальные значения  - очень высокое количество заказов, поскольку это был последний месяц наблюдений, сложно сделать вывод о "аномальности" и возможности заменить на средние значения
# 4. Применили модель Линейной регрессии, меняли количество шагов назад, с которыми мы обучали модель. Лучший результат на тестовой выборке показала модель с 24 лагами, RMSE составила 43
# 5. Применили модель LightGBM, лучший результат оказался при 100  estimators, num_leaves = 5, max_depth = 50, learning rate = 0.245
# Значение RMSE на тестовой выборке составило 47 - как и у модели линейной регрессии.
# Судя по графику, наша модель далека от идеала

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть итоговый вывод о проделанной работе - отлично!
# </div>

# %% [markdown]
# Очень оказалась сложная тема: очень много непонятного, убирать ли тренд и сезонность, как правильно предстазывать, я хотела применить модель Хольта Винтерса (рассазывали нам на вебинаре), но у меня не получилось. Очень много статей на эту тему в towardsdatascience и тп, но общей картины не складывается. Посоветуй, пожалуйста, как правильно к освоению этой темы подойти. Сейчас ощущение, что брожу на ощупь, там одно посмотреала, там другое - компиляция с очень ограниченным пониманием.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Юлия, ты хорошо потрудилась над этим проектом - работа получилось на довольно высоком уровне!
#
# Ты верно выполнила все задания проекта, последовательно прошла все его шаги, получила верные выводы и ничего не упустила в процессе - это классно, ты молодец!
#
# Ты хорошо используешь визуализацию, умело подбираешь тип графиков для объяснения данных. Понравилось также, что ты не ограничилась использованием простеньких алгоритмов типа линейной регрессии, а использовала более продвинутые инструменты бустинга. Также реализован механизм подбора гиперпараметров моделей с учётом специфики временного ряда - несомненный плюс! Также здорово, что в конце работы сравнила предсказанные и истинные значения для понимания узких зон модели - тоже плюс!
#
# Критических замечаний по проекту нет, но над проектом стоит ещё чуть-чуть поработать поработать: свои рекомендации по его улучшению, касающиеся как оформления, так и аналитической/модельной части, я оставил в комментариях жёлтого цвета. Будет здорово, если ты учтёшь эти комментарии во время следующей итерации работы над проектом - тогда ценность твоего проекта сильно возрастёт. Кроме того, есть кое-какие рекомендации по улучшению общего качества твоих моделей. Они носят характер рекомендаций и выделены зелёным цветом. К исполнению не обязательны, но если хочешь сделать лучше - можем попробовать:)
#
# Если по тому, что нужно сделать, будут вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью:)
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)
